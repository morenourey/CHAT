# %% [markdown]
# <a href="https://colab.research.google.com/github/morenourey/CHAT/blob/main/Autoreport_AutoML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/DS/DSC/2805/heart_statlog_cleveland_hungary_final.csv')
df
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 1      49    0                3           160          180
# 2      37    1                2           130          283
# 3      48    0                4           138          214
# 4      54    1                3           150          195
# ...   ...  ...              ...           ...          ...
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 1                       0            0             156                0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1190 entries, 0 to 1189
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  1190 non-null   int64
#  1   sex                  1190 non-null   int64
#  2   chest pain type      1190 non-null   int64
#  3   resting bp s         1190 non-null   int64
#  4   cholesterol          1190 non-null   int64
#  5   fasting blood sugar  1190 non-null   int64
#  6   resting ecg          1190 non-null   int64
#  7   max heart rate       1190 non-null   int64
#  8   exercise angina      1190 non-null   int64
#  9   oldpeak              1190 non-null   float64
#  10  ST slope             1190 non-null   int64
#  11  target               1190 non-null   int64
# dtypes: float64(1), int64(11)
# memory usage: 111.7 KB

# %%
df.describe()
# Out:
#                age          sex  chest pain type  resting bp s  cholesterol  \
# count  1190.000000  1190.000000      1190.000000   1190.000000  1190.000000
# mean     53.720168     0.763866         3.232773    132.153782   210.363866
# std       9.358203     0.424884         0.935480     18.368823   101.420489
# min      28.000000     0.000000         1.000000      0.000000     0.000000
# 25%      47.000000     1.000000         3.000000    120.000000   188.000000
# 50%      54.000000     1.000000         4.000000    130.000000   229.000000
# 75%      60.000000     1.000000         4.000000    140.000000   269.750000
# max      77.000000     1.000000         4.000000    200.000000   603.000000
#
#        fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# count          1190.000000  1190.000000     1190.000000      1190.000000
# mean              0.213445     0.698319      139.732773         0.387395
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = 20,10
sns.heatmap(df.corr(),cmap='viridis_r',annot= True)
plt.title("the correlation coefficient between the variables",size = 25);

# %%
# !pip install ydata-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 359.5/359.5 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 6.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 686.1/686.1 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 10.9 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27080 sha256=b8acc21beefc46fdd631dd014e1dda0b6d3fcc67c39e5598cb4e91a2f4aa77a8
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df,title = 'Heart Disease')
profile.to_notebook_iframe()
profile.to_file("books_data.html")
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v4.8.3&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-05-23 22:28:06.374989&quot;&gt;&lt;title&gt;Heart Disease&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df.isna().sum()
# Out:
# age                    0
# sex                    0
# chest pain type        0
# resting bp s           0
# cholesterol            0
# fasting blood sugar    0
# resting ecg            0
# max heart rate         0
# exercise angina        0
# oldpeak                0
# ST slope               0
# target                 0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 1      49    0                3           160          180
# 2      37    1                2           130          283
# 3      48    0                4           138          214
# 4      54    1                3           150          195
# ...   ...  ...              ...           ...          ...
# 1185   45    1                1           110          264
# 1186   68    1                4           144          193
# 1187   57    1                4           130          131
# 1188   57    0                2           130          236
# 1189   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 1                       0            0             156                0
# ...

# %%
y = df['target']
X = df.drop('target',axis = 1)

# %%
print(X.shape)
print(y.shape)
# Out:
# (1190, 11)
# (1190,)

# %%
# !pip install AutoLogging-ML
# !pip install xgboost
# !pip install catboost
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 MB 3.0 MB/s eta 0:00:00
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(X,y,random_state = 42,test_size=0.3)

# %%
from AutoLogging_ML import AutoLogger
r,model =AutoLogger.train_and_log_classification(x_train,y_train,x_test,y_test,size='large')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
r
# Out:
#                               model  training-accuracy  training-precision  \
# 6               logistic regression          80.672269           80.666528
# 10  quadratic discriminant analysis          83.193277           83.209476
# 9      linear discriminant analysis          82.713085           82.721110
# 0                       naive bayes          82.833133           82.864326
# 3                          adaboost          86.074430           86.065588
# 1                     decision tree         100.000000          100.000000
# 7                bagging classifier          99.399760           99.393992
# 5                           xgboost         100.000000          100.000000
# 8            extra trees classifier         100.000000          100.000000
# 4                    gradient boost          95.318127           95.333368
# 2                     random forest         100.000000          100.000000
#
#     training-recall  training-f1 training-confusion matrix  \
# ...

# %% [markdown]
# - training-accuracy: Exactitud del modelo en el conjunto de entrenamiento.
# - training-precision: Precisión del modelo en el conjunto de entrenamiento.
# - training-recall: Sensibilidad del modelo en el conjunto de entrenamiento.
# - training-f1: Puntuación F1 del modelo en el conjunto de entrenamiento.
# - training-confusion matrix: Matriz de confusión del modelo en el conjunto de entrenamiento.
# - validation-accuracy: Exactitud del modelo en el conjunto de validación.
# - validation-precision: Precisión del modelo en el conjunto de validación.
# - validation-recall: Sensibilidad del modelo en el conjunto de validación.
# - validation-f1: Puntuación F1 del modelo en el conjunto de validación.
# - validation-confusion matrix: Matriz de confusión del modelo en el conjunto de - validación.
#
#
# Interpretación de Resultados
#
#
# - Modelos de Alta Precisión y Exactitud: Los modelos como el bagging classifier, random forest, y extra trees classifier tienen altas métricas de rendimiento tanto en el conjunto de entrenamiento como en el de validación, con exactitudes de validación superiores al 90%.
#
# - Sobreajuste en Algunos Modelos: El decision tree muestra una precisión del 100% en el conjunto de entrenamiento, pero una menor en el conjunto de validación, lo que indica overfitting.
#
# - Rendimiento de Modelos Simples: Modelos más simples como logistic regression, naive bayes y linear discriminant analysis tienen menores exactitudes en comparación con los modelos más complejos, pero aún así proporcionan buenos resultados.

# %%
AutoLogger.get_classification_report(r,'validation')
# Out:
# logistic regression
#               precision    recall  f1-score   support
#
#            0       0.82      0.82      0.82       154
#            1       0.86      0.86      0.86       203
#
#     accuracy                           0.84       357
#    macro avg       0.84      0.84      0.84       357
# weighted avg       0.84      0.84      0.84       357
#
# quadratic discriminant analysis
#               precision    recall  f1-score   support
#
#            0       0.85      0.80      0.82       154
#            1       0.85      0.89      0.87       203
#
#     accuracy                           0.85       357
#    macro avg       0.85      0.85      0.85       357
# weighted avg       0.85      0.85      0.85       357
#
# linear discriminant analysis
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       154
#            1       0.87      0.87      0.87       203
#
#     accuracy                           0.85       357
# ...

# %%
AutoLogger.get_metric_plot_classification(r,'validation','accuracy')
# Out:
# <Axes: xlabel='validation-accuracy', ylabel='model'>

# %%
AutoLogger.sort_table_by_metric
r
# Out:
#                               model  training-accuracy  training-precision  \
# 6               logistic regression          80.672269           80.666528
# 10  quadratic discriminant analysis          83.193277           83.209476
# 9      linear discriminant analysis          82.713085           82.721110
# 0                       naive bayes          82.833133           82.864326
# 3                          adaboost          86.074430           86.065588
# 1                     decision tree         100.000000          100.000000
# 7                bagging classifier          99.399760           99.393992
# 5                           xgboost         100.000000          100.000000
# 8            extra trees classifier         100.000000          100.000000
# 4                    gradient boost          95.318127           95.333368
# 2                     random forest         100.000000          100.000000
#
#     training-recall  training-f1 training-confusion matrix  \
# ...

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score, classification_report
import numpy as np


# Supongamos que X y y son tus datos de características y etiquetas
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Crear y entrenar el modelo CatBoostClassifier
model = CatBoostClassifier(iterations=1000, learning_rate=0.1, depth=6, verbose=100)
model.fit(X_train, y_train)

# Realizar predicciones
y_pred = model.predict(X_test)

# Evaluar el rendimiento del modelo
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print(classification_report(y_test, y_pred))

# Opcional: visualizar la importancia de las características
import matplotlib.pyplot as plt

feature_importances = model.get_feature_importance()
feature_names = X.columns

plt.figure(figsize=(10, 6))
plt.barh(feature_names, feature_importances)
plt.xlabel("Feature Importance")
plt.title("Feature Importance in CatBoost Model")
plt.show()
# Out:
# 0:	learn: 0.6254931	total: 47.6ms	remaining: 47.6s
# 100:	learn: 0.1133165	total: 167ms	remaining: 1.48s
# 200:	learn: 0.0416726	total: 281ms	remaining: 1.11s
# 300:	learn: 0.0250602	total: 503ms	remaining: 1.17s
# 400:	learn: 0.0174392	total: 677ms	remaining: 1.01s
# 500:	learn: 0.0135462	total: 805ms	remaining: 802ms
# 600:	learn: 0.0110181	total: 914ms	remaining: 607ms
# 700:	learn: 0.0087851	total: 1.03s	remaining: 440ms
# 800:	learn: 0.0082767	total: 1.14s	remaining: 282ms
# 900:	learn: 0.0078861	total: 1.24s	remaining: 137ms
# 999:	learn: 0.0077121	total: 1.35s	remaining: 0us
# Accuracy: 0.927170868347339
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.92       154
#            1       0.93      0.94      0.94       203
#
#     accuracy                           0.93       357
#    macro avg       0.93      0.92      0.93       357
# weighted avg       0.93      0.93      0.93       357
